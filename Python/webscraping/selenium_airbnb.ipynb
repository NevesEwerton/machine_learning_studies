# %%
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from time import sleep
import pandas as pd

# %%
options = Options()
# não mostra o navegador aberto
# options.add_argument('--headless')
options.add_argument('window-size=400,800')
navegador = webdriver.Chrome(options=options)
navegador.get('https://www.airbnb.com.br/')

sleep(2)

input_place = navegador.find_element_by_tag_name('input')

input_place.send_keys('Sao Paulo')

input_place.submit()

sleep(0.5)


# encontra o botão dizendo que logo depois vem uma tag imagem
navegador.find_element_by_css_selector('button > img')

button_stay.click()

sleep(0.5)

nextButton = navegador.find_elements_by_tag_name('button')[-1]
nextButton.click()

sleep(0.5)

searchButton = navegador.find_elements_by_tag_name('button')[-1]
searchButton.click()

sleep(4)

# convertendo em objeto BeautifulSoup
page_content = navegador.page_source

site = BeautifulSoup(page_content, 'html.parser')
print(site.prettify())
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13416/4291842119.py in <module>
#      12 input_place.send_keys('Sao Paulo')
#      13
# ---> 14 input_place.submit()
#      15
#      16 #site = BeautifulSoup(navegador.page_source, 'html.parser')
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in submit(self)
#      83         """Submits a form."""
#      84         if self._w3c:
# ---> 85             form = self.find_element(By.XPATH, "./ancestor-or-self::form")
#      86             self._parent.execute_script(
#      87                 "var e = arguments[0].ownerDocument.createEvent('Event');"
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in find_element(self, by, value)
#     656                 value = '[name="%s"]' % value
#     657
# ...

# %%
<button aria-describedby="searchInputDescriptionId" type="button" class="_7yxudmg l1ovpqvx dir dir-ltr"><div class="l1icnbzi dir dir-ltr"><svg xmlns="http://www.w3.org/2000/svg" viewBox="0 0 32 32" aria-hidden="true" role="presentation" focusable="false" style="display: block; height: 20px; width: 20px; fill: currentcolor;"><path d="M13 0a13 13 0 0 1 10.5 20.67l7.91 7.92-2.82 2.82-7.92-7.91A12.94 12.94 0 0 1 13 26a13 13 0 1 1 0-26zm0 4a9 9 0 1 0 0 18 9 9 0 0 0 0-18z"></path></svg></div><div class="cqqb46g f1i5ttay dir dir-ltr"><div class="p1b4e8cr f1i5ttay dir dir-ltr"><div class="i13th1u8 dir dir-ltr"><span class="czst4s7 dir dir-ltr">Qualquer lugar</span></div></div><div class="s1f5fdzj f1i5ttay dir dir-ltr" aria-hidden="true"><div class="i13th1u8 dir dir-ltr"><span class="czst4s7 dir dir-ltr">Qualquer semana</span></div><div class="sekvny6 dir dir-ltr" aria-hidden="true">•</div><div class="i13th1u8 i1py6ptz dir dir-ltr"><span class="czst4s7 dir dir-ltr">Hóspedes?</span></div></div></div></button>

# %%
options = Options()
# não mostra o navegador aberto
# options.add_argument('--headless')
options.add_argument('window-size=400,800')
navegador = webdriver.Chrome(options=options)

navegador.get('https://www.airbnb.com.br/')




#sleep(3)

# %%
navegador.find_elements_by_xpath('/html/body/div[5]/div/div/div[1]/div/div[3]/div/div[1]/div[1]/div[1]/div/div[1]/div/div/div/div[1]/div/button')[0].click()

# %%
elemento = navegador.find_elements_by_xpath('//*[@id="/homes-1-input"]')[0]

# %%
sleep(1.5)
elemento.send_keys('Rio de Janeiro')
elemento.submit()

# %%
# 1 dia
navegador.find_elements_by_xpath('//*[@id="micro-flex-chips"]/div[2]/div[2]/label')[0].click()

sleep(0.5)

# botão de próximo
navegador.find_elements_by_xpath('//*[@id="accordion-body-/homes-2"]/section/div/footer/button[2]/div')[0].click()

sleep(0.5)

# botão para definir o número de adultos
navegador.find_elements_by_xpath('//*[@id="stepper-adults"]/button[2]/span')[0].click()

sleep(0.5)

# botão de buscar
navegador.find_elements_by_xpath('//*[@id="vertical-tabs"]/div[3]/footer/button[2]/span[1]/span')[0].click()

# %%
//*[@id="/homes-1-input"]

# %%
page_content = navegador.page_source

site = BeautifulSoup(page_content, 'html.parser')
print(site.prettify())
# Out:
# <html class="js-focus-visible scrollbar-gutter dir native v1oc6b3k vgnbcm1 v1agkal2 vqw89vp vlugpmm g5l85gq" data-hyperloop-version="1" data-is-hyperloop="true" dir="ltr" lang="pt" style="--vh: 6.44px; --vw: 5px; --vw-unitless: 500; --vw-px: 500px;">
#  <head>
#   <style>
# ...

# %%
nome = site.find('div',attrs={'class':'fb4nyux s1cjsi4j dir dir-ltr'}).text
print(nome)
# Out:
# Chalé do Aconchego - Barra de Guaratiba

# %%
n_cama = site.find('span',attrs={'class':'dir dir-ltr'}).text
print(n_cama)
# Out:
# 1 cama

# %%
site.find('div',attrs={'class': '_1jo4hgw'}).text
# Out:
# 'R$521\xa0noite'

# %%
preco = site.find('span',attrs={'class': '_tyxjp1'}).text
print(preco)
# Out:
# R$521

# %%
site.find('div',attrs={'class':'fb4nyux s1cjsi4j dir dir-ltr'}).text
# Out:
# 'Chalé do Aconchego - Barra de Guaratiba'

# %%
rooms = site.findAll('div',attrs={'class':"c4mnd7m dir dir-ltr"})

for room in rooms:
    
    try:
    
        nome = room.find('span',attrs={'class':'t6mzqp7 dir dir-ltr'})
        n_cama = room.find('span',attrs={'class':'dir dir-ltr'})
        preco = room.find('span',attrs={'class': '_tyxjp1'})
        rating =  room.find('span', attrs={'class':'r1dxllyb dir dir-ltr'})
    
    
        # PRINTANDO OS TEXTOS ENCONTRADOS
        print(nome.text)
        print(n_cama.text)
    
        # CHECANDO SE OS CAMPOS ESTÃO VAZIOS
        # PREÇO
        if (preco):
            preco = preco
        
            print(preco.text)
    
        # RATING
        if (rating):
            rating = rating
        
            print(rating.text)
        
    except:
        print(f"Erro ao obter informações: {e}")
        
        
        
# Vamos usar a estrutura try/except para apertar o botão de troca de página. Caso que não tenha mais como passar de página,
# ele vai passar para o próximo no laço. 
try:
    next_button = navegador.find_elements_by_xpath('//*[@id="site-content"]/div/div[2]/div/div/div/div[2]')[0]
    next_button.click()
    sleep(2) # ESPERA PARA A PRÓXIMA PÁGINA CARREGAR COMPLETAMENTE
except:
    print(f"Não há mais páginas disponíveis. Encerrando o processo.")
    exit()
# Out:
# Chalé do Aconchego - Barra de Guaratiba
# 1 cama
# R$521
# 4,96 (183)
# Nui Container - Refúgio natural no Rio de Janeiro
# 2 camas
# R$779
# 4,98 (43)
# Lindo Flat vista Mar - Barra da Tijuca
# 1 cama
# R$288
# Novo
# Quarto da mamãe simpático e silencioso
# Hospede-se com Izabella
# R$79
# 4,52 (33)
# Recanto junto a Natureza HIDRO/TV SMART/AR/WI-FI
# 2 camas
# R$313
# 4,88 (66)
# Quarto suíte no Recreio
# Hospede-se com Condita
# R$95
# 5,0 (7)
# Seu espaço próximo ao metrô.
# Hospede-se com Maria Graciosa
# R$90
# 5,0 (236)
# Lindo Flat acesso a pé a praia Barra da Tijuca
# 1 cama
# R$274
# 5,0 (10)
# cobertura da piscina com VISTA PARA O MAR
# 3 camas
# R$235
# Novo
# Casa da Praia da Brisa.
# 2 camas
# R$454
# 4,88 (26)
# Apartamento Encantador frente ao Mar! Posto 7
# 1 cama de casal
# R$402
# 4,68 (59)
# Aconchegante apto na urca.
# 1 cama
# R$195
# 5,0 (3)
# Suíte, piscina e academia | BPremium T1 Z10
# 1 cama king
# 4,32 (31)
# ...

# %%
teste = site.find('div',attrs={'itemprop':"itemListElement"})

#print(teste.prettify())


hosp_desc = teste.find('meta', attrs={'itemprop':'name'})

link = teste.find('meta', attrs={'itemprop':'url'})

car = teste.find('div', attrs={'data-testid':'listing-card-subtitle'})

hosp_detalhes =  teste.find('div', attrs={'style':'margin-bottom: 2px;'})

print("Nome: ", hosp_desc['content'])
print('Link: ', link['content'])
print('Descrição: ', car.text)
print(hosp_detalhes)
# Out:
# Nome:  Chalé do Aconchego - Barra de Guaratiba
# Link:  www.airbnb.com.br/rooms/567377133468945647?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-01-04&check_out=2024-01-09&source_impression_id=p3_1700742207_SrvM5UR3nrUl1HKf&previous_page_section_name=1000
# Descrição:  Chalé do Aconchego - Barra de Guaratiba
# None

# %%
print(teste.prettify())
# Out:
# <div itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem">
#  <meta content="Chalé do Aconchego - Barra de Guaratiba" itemprop="name"/>
#  <meta content="1" itemprop="position"/>
#  <meta content="www.airbnb.com.br/rooms/567377133468945647?adults=1&amp;children=0&amp;enable_m3_private_room=true&amp;infants=0&amp;pets=0&amp;check_in=2024-01-04&amp;check_out=2024-01-09&amp;source_impression_id=p3_1700704675_8w7FFON05IQnTS0%2B&amp;previous_page_section_name=1000" itemprop="url"/>
#  <div>
#   <div>
#    <div aria-labelledby="title_567377133468945647" class="cy5jw6o dir dir-ltr" data-testid="card-container" role="group">
# ...

# %%
rating =  teste.find('span', attrs={'class':'r1dxllyb dir dir-ltr'})

print(rating.text)
# Out:
# 4,96 (183)
